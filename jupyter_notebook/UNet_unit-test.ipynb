# %%
import torch 
import torch.nn as nn

import functools
import os
import sys 

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from models import networks

def instance_norm(dimension, affine = False):
    if dimension == 2:
        return nn.InstanceNorm2d

    elif dimension == 3:
        return nn.InstanceNorm3d

    else:
        raise Exception('Invalid image dimension.')
    
norm_layer = functools.partial(instance_norm(3), affine=False, track_running_stats=True)

model = networks.UNet3DAnisotropic(1, 1,norm_layer)

# %%
x = torch.randn((1, 1, 128, 128, 10))  # Batch of 1, grayscale, 3D image
output = model(x)
print(output.shape)  # Should be torch.Size([1, 1, 256, 256, 24])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 2
#       1 x = torch.randn((1, 1, 128, 128, 10))  # Batch of 1, grayscale, 3D image
# ----> 2 output = model(x)
#       3 print(output.shape)  # Should be torch.Size([1, 1, 256, 256, 24])
#
# File /g/prevedel/members/Park/miniforge3/envs/deepclarity/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /g/prevedel/members/Park/miniforge3/envs/deepclarity/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /g/kreshuk/park/code/neuroclear/models/networks.py:533, in Unet_deconv.forward(self, inputs)
#     529 conv_bottom = self.bottom_layer(maxpool2)
#     531 t_conv2 = self.t_conv2(conv_bottom)
# --> 533 cat2 = torch.cat([conv2, t_conv2], 1)
#     535 ex_conv2 = self.ex_double_conv2(cat2)
#     537 t_conv1 = self.t_conv1(ex_conv2)
#
# RuntimeError: Sizes of tensors must match except in dimension 1. Expected size 5 but got size 4 for tensor number 1 in the list.

# %%
model = networks.Unet_deconv(1, 1,norm_layer)

# %%
x = torch.randn((1, 1, 128, 128, 128))  # Batch of 1, grayscale, 3D image
output = model(x)
print(output.shape)  # Should be torch.Size([1, 1, 256, 256, 24])
# Out:
# torch.Size([1, 1, 128, 128, 128])

# %%
x = torch.randn((1, 1, 128, 128, 24))  # Batch of 1, grayscale, 3D image
output = model(x)
print(output.shape)  # Should be torch.Size([1, 1, 256, 256, 24])
# Out:
# torch.Size([1, 1, 128, 128, 24])
