# %% [markdown]
# ### In this notebook, we generate a 3D synthetic volume with a randomized mesh network of tubular objects.
#
#
# Code writer: Hyoungjun Park
#
# Contact: peterpark828@icloud.com OR peterpark828@kaist.ac.kr

# %%
from matplotlib import pyplot as plt 
import numpy as np
import os
import math
import sys

from tifffile import imwrite
import scipy.ndimage as ndimage
import scipy.signal as signal
# %matplotlib inline
from skimage.draw import line_nd
from skimage.draw import line_aa
from skimage.draw import line

import elasticdeform
import os

# %%
def normalize(img_np, invert=False):
    img_min = np.min(img_np)
    img_max = np.max(img_np)

    new_min = 0
    new_max = 1
    img_normd = (img_np - img_min) * ((new_max - new_min) / (img_max - img_min)) + new_min

    if invert:
        img_normd = new_max - img_normd

    return img_normd

# %% [markdown]
# ----

# %% [markdown]
# Set parameters.

# %%
std = 4 # std of Gaussian blurring 
ROI_size = 700 # dimension of the synthetic volume per axis. 
object_num = 6000 # number of objects for lines 

sigma_=2 #deformation parameter
points_=50 #deformation parameter

# %% [markdown]
# Save directory.

# %%
parent_dir = '/scratch/park/data/simulation_data/haystack_comparison'
if not os.path.isdir(parent_dir):
    os.makedirs(parent_dir)

psf_file_name = f'{object_num}-lines-blurred-by-gaublur-std-' +str(std)
model = 'haystack'
save_dir = os.path.join(parent_dir, 'simulation_data/', model, psf_file_name)

# %%
save_dir
# Out:
# '/scratch/park/data/simulation_data/haystack_comparison/simulation_data/haystack/6000-lines-blurred-by-gaublur-std-4'

# %% [markdown]
# Save directory for before-deformation.

# %%
save_before_deform_dir = os.path.join(save_dir, 'before_deform')
print(save_before_deform_dir)
if not os.path.isdir(save_before_deform_dir):
    os.makedirs(save_before_deform_dir)
# Out:
# /scratch/park/data/simulation_data/haystack_comparison/simulation_data/haystack/6000-lines-blurred-by-gaublur-std-4/before_deform

# %% [markdown]
# Save directory for Ground-truth

# %%
GT_deform_dir = os.path.join(save_dir, 'GT')
print(GT_deform_dir)
if not os.path.isdir(GT_deform_dir):
    os.makedirs(GT_deform_dir)
# Out:
# /scratch/park/data/simulation_data/haystack_comparison/simulation_data/haystack/6000-lines-blurred-by-gaublur-std-4/GT

# %% [markdown]
# Save dirtecotry for Blurring

# %%
blurred_deform_dir = os.path.join(save_dir, 'blurred')

if not os.path.isdir(blurred_deform_dir):
    os.makedirs(blurred_deform_dir)

# %% [markdown]
# Save dirtecotry for Blurring after 90-degree rotation.

# %%
blurred_xz_deform_dir = os.path.join(save_dir, 'rotated_xz_blurred')

print(blurred_xz_deform_dir)
if not os.path.isdir(blurred_xz_deform_dir):
    os.makedirs(blurred_xz_deform_dir)
# Out:
# /scratch/park/data/simulation_data/haystack_comparison/simulation_data/haystack/6000-lines-blurred-by-gaublur-std-4/rotated_xz_blurred

# %% [markdown]
# Test drawing one random line.

# %%
start_x = np.random.randint(0,ROI_size)
end_x = np.random.randint(0, ROI_size)
start_y = np.random.randint(0,ROI_size)
end_y = np.random.randint(0, ROI_size)

# %%
line_pts = line_aa(start_x, end_x, start_y, end_y)

# %%
line_pts
# Out:
# (array([603, 602, 603, 602, 601, 602, 601, 601, 600, 601, 600, 599, 600,
#         599, 598, 599, 598, 597, 598, 597, 597, 596, 596, 595, 596, 595,
#         594, 595, 594, 593, 594, 593, 592, 593, 592, 592, 591, 592, 591,
#         590, 591, 590, 589, 590, 589, 588, 589, 588, 588, 587, 588, 587,
#         586, 587, 586, 585, 586, 585, 584, 585, 584, 584, 583, 583, 582,
#         583, 582, 581, 582, 581, 580, 581, 580, 579, 580, 579, 579, 578,
#         579, 578, 577, 578, 577, 576, 577, 576, 575, 576, 575, 575, 574,
#         575, 574, 573, 574, 573, 572, 573, 572, 571, 572, 571, 571, 570,
#         571, 570, 569, 570, 569, 568, 569, 568, 567, 568, 567, 567, 566,
#         566, 565, 566, 565, 564, 565, 564, 563, 564, 563, 562, 563, 562,
#         562, 561, 562, 561, 560, 561, 560, 559, 560, 559, 558, 559, 558,
#         558, 557, 558, 557, 556, 557, 556, 555, 556, 555, 554, 555, 554,
#         554, 553, 553, 552, 553, 552, 551, 552, 551, 550, 551, 550, 549,
#         550, 549, 549, 548, 549, 548, 547, 548, 547, 546, 547, 546, 545,
#         546, 545, 545, 544, 545, 544, 543, 544, 543, 542, 543, 542, 541,
#         542, 541, 541, 540, 540, 539, 540, 539, 538, 539, 538, 537, 538,
#         537, 536, 537, 536, 536, 535, 536, 535, 534, 535, 534, 533, 534,
#         533, 532, 533, 532, 532, 531, 532, 531, 530, 531, 530, 529, 530,
#         529, 528, 529, 528, 528, 527, 527, 526, 527, 526, 525, 526, 525,
#         524, 525, 524, 523, 524, 523, 523, 522, 523, 522, 521, 522, 521,
#         520, 521, 520, 519, 520, 519, 519, 518, 519, 518, 517, 518, 517,
#         516, 517, 516, 515, 516, 515, 515, 514, 515, 514, 513, 514, 513,
#         512, 513, 512, 511, 512, 511, 511, 510, 510, 509, 510, 509, 508,
#         509, 508, 507, 508, 507, 506, 507, 506, 506, 505, 506, 505, 504,
#         505, 504, 503, 504, 503, 502, 503, 502, 502, 501, 502, 501, 500,
#         501, 500, 499, 500, 499, 498, 499, 498, 498, 497, 497, 496, 497,
#         496, 495, 496, 495, 494, 495, 494, 493, 494, 493, 493, 492, 493,
#         492, 491, 492, 491, 490, 491, 490, 489, 490, 489, 489, 488, 489,
#         488, 487, 488, 487, 486, 487, 486, 485, 486, 485, 485, 484, 484,
#         483, 484, 483, 482, 483, 482, 481, 482, 481, 480, 481, 480, 480,
#         479, 480, 479, 478, 479, 478, 477, 478, 477, 476, 477, 476, 476,
#         475, 476, 475, 474, 475, 474, 473, 474, 473, 472, 473, 472, 472,
#         471, 471, 470, 471, 470, 469, 470, 469, 468, 469, 468, 467, 468,
#         467, 467, 466, 467, 466, 465, 466, 465, 464, 465, 464, 463, 464,
#         463, 463, 462, 463, 462, 461, 462, 461, 460, 461, 460, 459, 460,
#         459, 459, 458, 459, 458, 457, 458, 457, 456, 457, 456, 455, 456,
#         455, 455, 454, 454, 453, 454, 453, 452, 453, 452, 451, 452, 451,
#         450, 451, 450, 450, 449, 450, 449, 448, 449, 448, 447, 448, 447,
#         446, 447, 446, 446, 445, 446, 445, 444, 445, 444, 443, 444, 443,
#         442, 443, 442, 442, 441, 441, 440, 441, 440, 439, 440, 439, 438,
#         439, 438, 437, 438, 437, 437, 436, 437, 436, 435, 436, 435, 434,
#         435, 434, 433, 434, 433, 433, 432, 433, 432, 431, 432, 431, 430,
#         431, 430, 429, 430, 429, 429, 428, 428, 427, 428, 427, 426, 427,
#         426, 425, 426, 425, 424, 425, 424, 424, 423, 424, 423, 422, 423,
#         422, 421, 422, 421, 420, 421, 420, 420, 419, 420, 419, 418, 419,
#         418, 417, 418, 417, 416, 417, 416, 416, 415, 415, 414, 415, 414,
#         413, 414, 413, 412, 413, 412, 411, 412, 411, 411, 410, 411, 410,
#         409, 410, 409, 408, 409, 408, 407, 408, 407, 407, 406, 407, 406,
#         405, 406, 405, 404, 405, 404, 403, 404, 403, 403, 402, 403, 402,
#         401, 402, 401, 400, 401, 400, 399, 400, 399, 399, 398, 398, 397,
#         398, 397, 396, 397, 396, 395, 396, 395, 394, 395, 394, 394, 393,
#         394, 393, 392, 393, 392, 391, 392, 391, 390, 391, 390, 390, 389,
#         390, 389, 388, 389, 388, 387, 388, 387, 386, 387, 386, 386, 385,
#         385, 384, 385, 384, 383, 384, 383, 382, 383, 382, 381, 382, 381,
#         381, 380, 381, 380, 379, 380, 379]),
#  array([240, 240, 241, 241, 241, 242, 242, 243, 243, 244, 244, 244, 245,
#         245, 245, 246, 246, 246, 247, 247, 248, 248, 249, 249, 250, 250,
#         250, 251, 251, 251, 252, 252, 252, 253, 253, 254, 254, 255, 255,
#         255, 256, 256, 256, 257, 257, 257, 258, 258, 259, 259, 260, 260,
#         260, 261, 261, 261, 262, 262, 262, 263, 263, 264, 264, 265, 265,
#         266, 266, 266, 267, 267, 267, 268, 268, 268, 269, 269, 270, 270,
#         271, 271, 271, 272, 272, 272, 273, 273, 273, 274, 274, 275, 275,
#         276, 276, 276, 277, 277, 277, 278, 278, 278, 279, 279, 280, 280,
#         281, 281, 281, 282, 282, 282, 283, 283, 283, 284, 284, 285, 285,
#         286, 286, 287, 287, 287, 288, 288, 288, 289, 289, 289, 290, 290,
#         291, 291, 292, 292, 292, 293, 293, 293, 294, 294, 294, 295, 295,
#         296, 296, 297, 297, 297, 298, 298, 298, 299, 299, 299, 300, 300,
#         301, 301, 302, 302, 303, 303, 303, 304, 304, 304, 305, 305, 305,
#         306, 306, 307, 307, 308, 308, 308, 309, 309, 309, 310, 310, 310,
#         311, 311, 312, 312, 313, 313, 313, 314, 314, 314, 315, 315, 315,
#         316, 316, 317, 317, 318, 318, 319, 319, 319, 320, 320, 320, 321,
#         321, 321, 322, 322, 323, 323, 324, 324, 324, 325, 325, 325, 326,
#         326, 326, 327, 327, 328, 328, 329, 329, 329, 330, 330, 330, 331,
#         331, 331, 332, 332, 333, 333, 334, 334, 335, 335, 335, 336, 336,
#         336, 337, 337, 337, 338, 338, 339, 339, 340, 340, 340, 341, 341,
#         341, 342, 342, 342, 343, 343, 344, 344, 345, 345, 345, 346, 346,
#         346, 347, 347, 347, 348, 348, 349, 349, 350, 350, 350, 351, 351,
#         351, 352, 352, 352, 353, 353, 354, 354, 355, 355, 356, 356, 356,
#         357, 357, 357, 358, 358, 358, 359, 359, 360, 360, 361, 361, 361,
#         362, 362, 362, 363, 363, 363, 364, 364, 365, 365, 366, 366, 366,
#         367, 367, 367, 368, 368, 368, 369, 369, 370, 370, 371, 371, 372,
#         372, 372, 373, 373, 373, 374, 374, 374, 375, 375, 376, 376, 377,
#         377, 377, 378, 378, 378, 379, 379, 379, 380, 380, 381, 381, 382,
#         382, 382, 383, 383, 383, 384, 384, 384, 385, 385, 386, 386, 387,
#         387, 388, 388, 388, 389, 389, 389, 390, 390, 390, 391, 391, 392,
#         392, 393, 393, 393, 394, 394, 394, 395, 395, 395, 396, 396, 397,
#         397, 398, 398, 398, 399, 399, 399, 400, 400, 400, 401, 401, 402,
#         402, 403, 403, 404, 404, 404, 405, 405, 405, 406, 406, 406, 407,
#         407, 408, 408, 409, 409, 409, 410, 410, 410, 411, 411, 411, 412,
#         412, 413, 413, 414, 414, 414, 415, 415, 415, 416, 416, 416, 417,
#         417, 418, 418, 419, 419, 419, 420, 420, 420, 421, 421, 421, 422,
#         422, 423, 423, 424, 424, 425, 425, 425, 426, 426, 426, 427, 427,
#         427, 428, 428, 429, 429, 430, 430, 430, 431, 431, 431, 432, 432,
#         432, 433, 433, 434, 434, 435, 435, 435, 436, 436, 436, 437, 437,
#         437, 438, 438, 439, 439, 440, 440, 441, 441, 441, 442, 442, 442,
#         443, 443, 443, 444, 444, 445, 445, 446, 446, 446, 447, 447, 447,
#         448, 448, 448, 449, 449, 450, 450, 451, 451, 451, 452, 452, 452,
#         453, 453, 453, 454, 454, 455, 455, 456, 456, 457, 457, 457, 458,
#         458, 458, 459, 459, 459, 460, 460, 461, 461, 462, 462, 462, 463,
#         463, 463, 464, 464, 464, 465, 465, 466, 466, 467, 467, 467, 468,
#         468, 468, 469, 469, 469, 470, 470, 471, 471, 472, 472, 473, 473,
#         473, 474, 474, 474, 475, 475, 475, 476, 476, 477, 477, 478, 478,
#         478, 479, 479, 479, 480, 480, 480, 481, 481, 482, 482, 483, 483,
#         483, 484, 484, 484, 485, 485, 485, 486, 486, 487, 487, 488, 488,
#         488, 489, 489, 489, 490, 490, 490, 491, 491, 492, 492, 493, 493,
#         494, 494, 494, 495, 495, 495, 496, 496, 496, 497, 497, 498, 498,
#         499, 499, 499, 500, 500, 500, 501, 501, 501, 502, 502, 503, 503,
#         504, 504, 504, 505, 505, 505, 506, 506, 506, 507, 507, 508, 508,
#         509, 509, 510, 510, 510, 511, 511, 511, 512, 512, 512, 513, 513,
#         514, 514, 515, 515, 515, 516, 516]),
#  array([1.        , 0.22354191, 0.36983111, 0.85371079, 0.0772527 ,
#         0.51612032, 0.70742159, 0.66240952, 0.56113238, 0.03224064,
#         0.80869873, 0.41484318, 0.17852984, 0.95498794, 0.26855397,
#         0.32481905, 0.89872286, 0.12226476, 0.47110825, 0.75243365,
#         0.61739746, 0.60614444, 0.76368667, 0.45985524, 0.13351778,
#         0.90997587, 0.31356603, 0.27980698, 0.94373492, 0.16727683,
#         0.42609619, 0.79744571, 0.02098762, 0.5723854 , 0.65115651,
#         0.7186746 , 0.5048673 , 0.08850572, 0.86496381, 0.3585781 ,
#         0.23479492, 0.98874698, 0.21228889, 0.38108413, 0.84245778,
#         0.06599968, 0.52737333, 0.69616857, 0.67366254, 0.54987937,
#         0.04349365, 0.81995175, 0.40359016, 0.18978286, 0.96624095,
#         0.25730095, 0.33607206, 0.88746984, 0.11101175, 0.48236127,
#         0.74118064, 0.62865048, 0.59489143, 0.77493968, 0.44860222,
#         0.14477079, 0.92122889, 0.30231302, 0.29106   , 0.9324819 ,
#         0.15602381, 0.43734921, 0.7861927 , 0.0097346 , 0.58363841,
#         0.63990349, 0.72992762, 0.49361429, 0.09975873, 0.87621683,
#         0.34732508, 0.24604794, 0.97749397, 0.20103587, 0.39233714,
#         0.83120476, 0.05474667, 0.53862635, 0.68491556, 0.68491556,
#         0.53862635, 0.05474667, 0.83120476, 0.39233714, 0.20103587,
#         0.97749397, 0.24604794, 0.34732508, 0.87621683, 0.09975873,
#         0.49361429, 0.72992762, 0.63990349, 0.58363841, 0.0097346 ,
#         0.7861927 , 0.43734921, 0.15602381, 0.9324819 , 0.29106   ,
#         0.30231302, 0.92122889, 0.14477079, 0.44860222, 0.77493968,
#         0.59489143, 0.62865048, 0.74118064, 0.48236127, 0.11101175,
#         0.88746984, 0.33607206, 0.25730095, 0.96624095, 0.18978286,
#         0.40359016, 0.81995175, 0.04349365, 0.54987937, 0.67366254,
#         0.69616857, 0.52737333, 0.06599968, 0.84245778, 0.38108413,
#         0.21228889, 0.98874698, 0.23479492, 0.3585781 , 0.86496381,
#         0.08850572, 0.5048673 , 0.7186746 , 0.65115651, 0.5723854 ,
#         0.02098762, 0.79744571, 0.42609619, 0.16727683, 0.94373492,
#         0.27980698, 0.31356603, 0.90997587, 0.13351778, 0.45985524,
#         0.76368667, 0.60614444, 0.61739746, 0.75243365, 0.47110825,
#         0.12226476, 0.89872286, 0.32481905, 0.26855397, 0.95498794,
#         0.17852984, 0.41484318, 0.80869873, 0.03224064, 0.56113238,
#         0.66240952, 0.70742159, 0.51612032, 0.0772527 , 0.85371079,
#         0.36983111, 0.22354191, 1.        , 0.22354191, 0.36983111,
#         0.85371079, 0.0772527 , 0.51612032, 0.70742159, 0.66240952,
#         0.56113238, 0.03224064, 0.80869873, 0.41484318, 0.17852984,
#         0.95498794, 0.26855397, 0.32481905, 0.89872286, 0.12226476,
#         0.47110825, 0.75243365, 0.61739746, 0.60614444, 0.76368667,
#         0.45985524, 0.13351778, 0.90997587, 0.31356603, 0.27980698,
#         0.94373492, 0.16727683, 0.42609619, 0.79744571, 0.02098762,
#         0.5723854 , 0.65115651, 0.7186746 , 0.5048673 , 0.08850572,
#         0.86496381, 0.3585781 , 0.23479492, 0.98874698, 0.21228889,
#         0.38108413, 0.84245778, 0.06599968, 0.52737333, 0.69616857,
#         0.67366254, 0.54987937, 0.04349365, 0.81995175, 0.40359016,
#         0.18978286, 0.96624095, 0.25730095, 0.33607206, 0.88746984,
#         0.11101175, 0.48236127, 0.74118064, 0.62865048, 0.59489143,
#         0.77493968, 0.44860222, 0.14477079, 0.92122889, 0.30231302,
#         0.29106   , 0.9324819 , 0.15602381, 0.43734921, 0.7861927 ,
#         0.0097346 , 0.58363841, 0.63990349, 0.72992762, 0.49361429,
#         0.09975873, 0.87621683, 0.34732508, 0.24604794, 0.97749397,
#         0.20103587, 0.39233714, 0.83120476, 0.05474667, 0.53862635,
#         0.68491556, 0.68491556, 0.53862635, 0.05474667, 0.83120476,
#         0.39233714, 0.20103587, 0.97749397, 0.24604794, 0.34732508,
#         0.87621683, 0.09975873, 0.49361429, 0.72992762, 0.63990349,
#         0.58363841, 0.0097346 , 0.7861927 , 0.43734921, 0.15602381,
#         0.9324819 , 0.29106   , 0.30231302, 0.92122889, 0.14477079,
#         0.44860222, 0.77493968, 0.59489143, 0.62865048, 0.74118064,
#         0.48236127, 0.11101175, 0.88746984, 0.33607206, 0.25730095,
#         0.96624095, 0.18978286, 0.40359016, 0.81995175, 0.04349365,
#         0.54987937, 0.67366254, 0.69616857, 0.52737333, 0.06599968,
#         0.84245778, 0.38108413, 0.21228889, 0.98874698, 0.23479492,
#         0.3585781 , 0.86496381, 0.08850572, 0.5048673 , 0.7186746 ,
#         0.65115651, 0.5723854 , 0.02098762, 0.79744571, 0.42609619,
#         0.16727683, 0.94373492, 0.27980698, 0.31356603, 0.90997587,
#         0.13351778, 0.45985524, 0.76368667, 0.60614444, 0.61739746,
#         0.75243365, 0.47110825, 0.12226476, 0.89872286, 0.32481905,
#         0.26855397, 0.95498794, 0.17852984, 0.41484318, 0.80869873,
#         0.03224064, 0.56113238, 0.66240952, 0.70742159, 0.51612032,
#         0.0772527 , 0.85371079, 0.36983111, 0.22354191, 1.        ,
#         0.22354191, 0.36983111, 0.85371079, 0.0772527 , 0.51612032,
#         0.70742159, 0.66240952, 0.56113238, 0.03224064, 0.80869873,
#         0.41484318, 0.17852984, 0.95498794, 0.26855397, 0.32481905,
#         0.89872286, 0.12226476, 0.47110825, 0.75243365, 0.61739746,
#         0.60614444, 0.76368667, 0.45985524, 0.13351778, 0.90997587,
#         0.31356603, 0.27980698, 0.94373492, 0.16727683, 0.42609619,
#         0.79744571, 0.02098762, 0.5723854 , 0.65115651, 0.7186746 ,
#         0.5048673 , 0.08850572, 0.86496381, 0.3585781 , 0.23479492,
#         0.98874698, 0.21228889, 0.38108413, 0.84245778, 0.06599968,
#         0.52737333, 0.69616857, 0.67366254, 0.54987937, 0.04349365,
#         0.81995175, 0.40359016, 0.18978286, 0.96624095, 0.25730095,
#         0.33607206, 0.88746984, 0.11101175, 0.48236127, 0.74118064,
#         0.62865048, 0.59489143, 0.77493968, 0.44860222, 0.14477079,
#         0.92122889, 0.30231302, 0.29106   , 0.9324819 , 0.15602381,
#         0.43734921, 0.7861927 , 0.0097346 , 0.58363841, 0.63990349,
#         0.72992762, 0.49361429, 0.09975873, 0.87621683, 0.34732508,
#         0.24604794, 0.97749397, 0.20103587, 0.39233714, 0.83120476,
#         0.05474667, 0.53862635, 0.68491556, 0.68491556, 0.53862635,
#         0.05474667, 0.83120476, 0.39233714, 0.20103587, 0.97749397,
#         0.24604794, 0.34732508, 0.87621683, 0.09975873, 0.49361429,
#         0.72992762, 0.63990349, 0.58363841, 0.0097346 , 0.7861927 ,
#         0.43734921, 0.15602381, 0.9324819 , 0.29106   , 0.30231302,
#         0.92122889, 0.14477079, 0.44860222, 0.77493968, 0.59489143,
#         0.62865048, 0.74118064, 0.48236127, 0.11101175, 0.88746984,
#         0.33607206, 0.25730095, 0.96624095, 0.18978286, 0.40359016,
#         0.81995175, 0.04349365, 0.54987937, 0.67366254, 0.69616857,
#         0.52737333, 0.06599968, 0.84245778, 0.38108413, 0.21228889,
#         0.98874698, 0.23479492, 0.3585781 , 0.86496381, 0.08850572,
#         0.5048673 , 0.7186746 , 0.65115651, 0.5723854 , 0.02098762,
#         0.79744571, 0.42609619, 0.16727683, 0.94373492, 0.27980698,
#         0.31356603, 0.90997587, 0.13351778, 0.45985524, 0.76368667,
#         0.60614444, 0.61739746, 0.75243365, 0.47110825, 0.12226476,
#         0.89872286, 0.32481905, 0.26855397, 0.95498794, 0.17852984,
#         0.41484318, 0.80869873, 0.03224064, 0.56113238, 0.66240952,
#         0.70742159, 0.51612032, 0.0772527 , 0.85371079, 0.36983111,
#         0.22354191, 1.        , 0.22354191, 0.36983111, 0.85371079,
#         0.0772527 , 0.51612032, 0.70742159, 0.66240952, 0.56113238,
#         0.03224064, 0.80869873, 0.41484318, 0.17852984, 0.95498794,
#         0.26855397, 0.32481905, 0.89872286, 0.12226476, 0.47110825,
#         0.75243365, 0.61739746, 0.60614444, 0.76368667, 0.45985524,
#         0.13351778, 0.90997587, 0.31356603, 0.27980698, 0.94373492,
#         0.16727683, 0.42609619, 0.79744571, 0.02098762, 0.5723854 ,
#         0.65115651, 0.7186746 , 0.5048673 , 0.08850572, 0.86496381,
#         0.3585781 , 0.23479492, 0.98874698, 0.21228889, 0.38108413,
#         0.84245778, 0.06599968, 0.52737333, 0.69616857, 0.67366254,
#         0.54987937, 0.04349365, 0.81995175, 0.40359016, 0.18978286,
#         0.96624095, 0.25730095, 0.33607206, 0.88746984, 0.11101175,
#         0.48236127, 0.74118064, 0.62865048, 0.59489143, 0.77493968,
#         0.44860222, 0.14477079, 0.92122889, 0.30231302, 0.29106   ,
#         0.9324819 , 0.15602381, 0.43734921, 0.7861927 , 0.0097346 ,
#         0.58363841, 0.63990349, 0.72992762, 0.49361429, 0.09975873,
#         0.87621683, 0.34732508, 0.24604794, 0.97749397, 0.20103587,
#         0.39233714, 0.83120476, 0.05474667, 0.53862635, 0.68491556,
#         0.68491556, 0.53862635, 0.05474667, 0.83120476, 0.39233714,
#         0.20103587, 0.97749397, 0.24604794, 0.34732508, 0.87621683,
#         0.09975873, 0.49361429, 0.72992762, 0.63990349, 0.58363841,
#         0.0097346 , 0.7861927 , 0.43734921, 0.15602381, 0.9324819 ,
#         0.29106   , 0.30231302, 0.92122889, 0.14477079, 0.44860222,
#         0.77493968, 0.59489143, 0.62865048, 0.74118064, 0.48236127,
#         0.11101175, 0.88746984, 0.33607206, 0.25730095, 0.96624095,
#         0.18978286, 0.40359016, 0.81995175, 0.04349365, 0.54987937,
#         0.67366254, 0.69616857, 0.52737333, 0.06599968, 0.84245778,
#         0.38108413, 0.21228889, 0.98874698, 0.23479492, 0.3585781 ,
#         0.86496381, 0.08850572, 0.5048673 , 0.7186746 , 0.65115651,
#         0.5723854 , 0.02098762, 0.79744571, 0.42609619, 0.16727683,
#         0.94373492, 0.27980698, 0.31356603, 0.90997587, 0.13351778,
#         0.45985524, 0.76368667, 0.60614444, 0.61739746, 0.75243365,
#         0.47110825, 0.12226476, 0.89872286, 0.32481905, 0.26855397,
#         0.95498794, 0.17852984, 0.41484318, 0.80869873, 0.03224064,
#         0.56113238, 0.66240952, 0.70742159, 0.51612032, 0.0772527 ,
#         0.85371079, 0.36983111, 0.22354191, 1.        ]))

# %%
canvas = np.zeros((ROI_size,ROI_size))

# %%
for i in range(len(line_pts[0])):
    canvas[line_pts[0][i], line_pts[1][i]] = 100

# %%
plt.figure(figsize=(10,10))
plt.imshow(canvas, cmap = 'gray')

# %%
canvas = np.zeros((ROI_size,ROI_size))

# %%
for t in range(20):
    start_x = np.random.randint(0,ROI_size)
    end_x = np.random.randint(0, ROI_size)
    start_y = np.random.randint(0,ROI_size)
    end_y = np.random.randint(0, ROI_size)
    
    line_pts = line_aa(start_x, end_x, start_y, end_y)
    
    for i in range(len(line_pts[0])):
        canvas[line_pts[0][i], line_pts[1][i]] = 100

# %% [markdown]
# Test deformation.

# %%
plt.figure(figsize=(10,10))
# X = np.zeros((200, 300))
# X[::10, ::10] = 1
# apply deformation with a random 3 x 3 grid
canvas_vol = elasticdeform.deform_random_grid(canvas, sigma=2, points=20)
plt.imshow(canvas_vol, cmap = 'gray')

# %% [markdown]
# ## Now, 3D volume with random lines

# %%
start_x = np.random.randint(0,ROI_size)
end_x = np.random.randint(0, ROI_size)

start_y = np.random.randint(0,ROI_size)
end_y = np.random.randint(0, ROI_size)

start_z =  np.random.randint(0, ROI_size)
end_z =  np.random.randint(0, ROI_size)

# %%
canvas_vol = np.zeros((ROI_size, ROI_size, ROI_size))

# %%
for t in range(object_num):
    indice = [np.random.randint(0, ROI_size) for i in range(6)]
    
    start_pt, end_pt = indice[:3], indice[3:]
    
    line_pts = line_nd(start_pt, end_pt) 

    for i in range(len(line_pts[0])):
        canvas_vol[line_pts[0][i], line_pts[1][i], line_pts[2][i]] = (2**16-1)*(2/3)

# %% [markdown]
# ### Slice

# %%
plt.figure(figsize=(10,10))
# X = np.zeros((200, 300))
# X[::10, ::10] = 1
# apply deformation with a random 3 x 3 grid
plt.imshow(canvas_vol[10], cmap = 'gray')

# %%
plt.figure(figsize=(10,10))
# X = np.zeros((200, 300))
# X[::10, ::10] = 1
# apply deformation with a random 3 x 3 grid
plt.imshow(np.amax(canvas_vol[100:150],0), cmap = 'gray')

# %% [markdown]
# ## Try convolving with 3D Gaussian or average filter to make the lines thicker.

# %%
from scipy import ndimage, misc

# %%
canvas_vol = ndimage.uniform_filter(canvas_vol, size=2)

# %%
canvas_vol[canvas_vol>100] = (2**16-1)*(2/3)

# %%
canvas_vol[canvas_vol<100] = 0

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(canvas_vol[10], cmap = 'gray')
axs[1].imshow(canvas_vol[60], cmap = 'gray')

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(np.amax(canvas_vol[80:110],0), cmap = 'gray')
axs[1].imshow(np.amax(canvas_vol[80:110],0), cmap = 'gray')

# %%
canvas_vol_save = canvas_vol.astype(np.uint16)

# %%
imwrite(save_before_deform_dir + '/before_deform.tiff', canvas_vol_save)

# %% [markdown]
# ------

# %% [markdown]
# ### Deform

# %%
canvas_vol = elasticdeform.deform_random_grid(canvas_vol, sigma=sigma_, points=points_)

# %%
np.min(canvas_vol), np.max(canvas_vol)
# Out:
# (-20177.84812293954, 72796.09428660634)

# %%
canvas_vol = np.clip(canvas_vol, 0, None)

# %%
np.min(canvas_vol), np.max(canvas_vol)
# Out:
# (0.0, 72796.09428660634)

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(np.amax(canvas_vol[80:110],0), cmap = 'gray')
axs[1].imshow(np.amax(canvas_vol[110:140],0), cmap = 'gray')

# %% [markdown]
# ### Save this as GT.

# %%
canvas_vol_save = (canvas_vol-np.mean(canvas_vol))/np.std(canvas_vol)
canvas_vol_save = normalize(canvas_vol_save) * (2**16-1)
canvas_vol_save = canvas_vol_save.astype(np.uint16)

# %%
imwrite(GT_deform_dir + '/GT.tiff', canvas_vol_save)

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(np.amax(canvas_vol_save[80:110],0), cmap = 'gray')
axs[1].imshow(np.amax(canvas_vol_save[110:140],0), cmap = 'gray')

# %% [markdown]
# ----

# %% [markdown]
# # Convolve with Z-Gaussian

# %%
canvas_vol = (canvas_vol-np.mean(canvas_vol))/np.std(canvas_vol)

# %%
canvas_vol = normalize(canvas_vol)

# %%
fitler_size = 31

# %%
gau_filter_ = signal.gaussian(fitler_size,std)
# gau_filter_ = np.reshape(gau_filter_, (1,31))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 gau_filter_ = signal.gaussian(fitler_size,std)
#       2 # gau_filter_ = np.reshape(gau_filter_, (1,31))
#
# AttributeError: module 'scipy.signal' has no attribute 'gaussian'

# %%
plt.figure()
plt.plot(gau_filter_.squeeze())

# %%
gau_filter = np.zeros((fitler_size,fitler_size,fitler_size))

# %%
middle = int(gau_filter_.shape[0]/2)
print(middle)
gau_filter[:,middle,middle] = gau_filter_

# %%
canvas_vol_blurred = signal.fftconvolve(canvas_vol, gau_filter, mode='same')

# %%
canvas_vol_blurred_save = (canvas_vol_blurred-np.mean(canvas_vol_blurred))/np.std(canvas_vol_blurred)
canvas_vol_blurred_save = normalize(canvas_vol_blurred_save) * (2**16-1)
canvas_vol_blurred_save = canvas_vol_blurred_save.astype(np.uint16)

# %% [markdown]
# Slice XY image comparison

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(canvas_vol[110], cmap = 'gray')
axs[1].imshow(canvas_vol_blurred[110], cmap = 'gray')

# %% [markdown]
# Slice XZ image comparison

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(canvas_vol[:,110,:], cmap = 'gray')
axs[1].imshow(canvas_vol_blurred[:,110,:], cmap = 'gray')

# %% [markdown]
# MIP XY image comparison

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(np.amax(canvas_vol[80:110],0), cmap = 'gray')
axs[1].imshow(np.amax(canvas_vol_blurred[80:110],0), cmap = 'gray')

# %% [markdown]
# MIP XZ image comparison

# %%
figs, axs = plt.subplots(1,2,figsize=(15,15))
figs = plt.figure(figsize=(10,10))
axs[0].imshow(np.amax(canvas_vol_blurred_save[80:110,:,:],0), cmap = 'gray')
axs[1].imshow(np.amax(canvas_vol_blurred_save[:,80:110,:],1), cmap = 'gray')

# %%
imwrite(blurred_deform_dir + '/blurred.tiff', canvas_vol_blurred_save)

# %% [markdown]
# ### Create the blurred volume after rotation (for comparison).

# %%
canvas_vol_rotated_xz = np.swapaxes(canvas_vol, 0,1) # (z,y,x) -> (y,z,x)
canvas_vol_rotated_xz = signal.fftconvolve(canvas_vol_rotated_xz, gau_filter, mode='same')

# %%
canvas_vol_rotated_xz_save = (canvas_vol_rotated_xz-np.mean(canvas_vol_rotated_xz))/np.std(canvas_vol_rotated_xz)
canvas_vol_rotated_xz_save = normalize(canvas_vol_rotated_xz_save) * (2**16-1)
canvas_vol_rotated_xz_save = canvas_vol_rotated_xz_save.astype(np.uint16)

# %%
imwrite(blurred_xz_deform_dir+'/rotated_xz_blurred.tiff', canvas_vol_rotated_xz_save)
